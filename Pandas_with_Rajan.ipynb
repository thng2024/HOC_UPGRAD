# %% [markdown]
# <a href="https://colab.research.google.com/github/thng2024/HOC_UPGRAD/blob/main/Pandas_with_Rajan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is Pandas ? 🐼
# ---
#
# Pandas is a powerful and easy to use library , primarily used for Data Analysis.
# <pre>
# Using Pandas we Can do
#
#   ➡️ Data PreProcessing / Cleaning (Primary)
#   ➡️ Data Manipulation
#   ➡️ Data Analysis (Primary)

# %% [markdown]
# Similar to Numpy , Pandas also Provides its OWN Data Structure
# <pre>
#       for STORING & Processing DATA.
#
#       these are
#
#             ⭐ Series
#             ⭐ DataFrame

# %% [markdown]
# ## When to Use Series & WHen to Use Dataframe ❓
# ---
#
# ⭐ Series : It is used to Store , Process and Analyse 1D or Linear Data eg. List in Python.
#
# ⭐ DataFrame : It is used to Store, Process and Analyse 2D or Tabular Data eg. SHeet in Excel.

# %%
#  Name         age       course
#  --------------------------
#  Miki         22         php
#  zhining      23         java
#  armanta      21         cSharp

# %% [markdown]
# # 🪻 Working with Series
# ---

# %%
# first, you must import pandas

import pandas as pd

# %%
# here is a sample List

stockPrices = [ 44.5 , 22.1 , 77.4 , 99.5 , 67.4 ]

# %% [markdown]
# 🍎 In Order to Have Access to Built in Analytical Functions of Pandas , I Must Convert List into Series using pd.Series() Function.

# %%
mySeries = pd.Series ( stockPrices )            #<------------------🍎

# %%
# what is mySeries ?
print( type(mySeries) )
# Out:
# <class 'pandas.core.series.Series'>

# %%
# what does mySeries Contains ?
mySeries
# Out:
# 0    44.5
# 1    22.1
# 2    77.4
# 3    99.5
# 4    67.4
# dtype: float64

# %% [markdown]
# # 💡 Quick Fact : Pandas uses ND Array Internally to Store Data.
#
# (Pandas is Built On Top of Numpy)

# %%
mySeries.values
# Out:
# array([44.5, 22.1, 77.4, 99.5, 67.4])

# %%
type(mySeries.values)
# Out:
# numpy.ndarray

# %%
# pandas has Access to ND Array Data Structure Functionalites Only and not Numpy.

# %%
mySeries.max()
# Out:
# 99.5

# %%
mySeries.sum()
# Out:
# 310.9

# %% [markdown]
# # 💻 Creating or Working with DataFrame
# ---
#
# Dataset Link :
# NBA : 🏀
#
# https://drive.google.com/file/d/1ZaNh_kZ5fIV7iXx350dDS2UbnSiJoRsD/view?usp=sharing

# %% [markdown]
# 💡pd.read_csv() : this function is used to read a CSV file and returns a DataFrame.

# %%
nba = pd.read_csv('nba.csv')

# %%
# what is nba ?
print( type(nba))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# what nba contains ?
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # 💻 Let Us Learn How to Do DataFrame Inspection !
# ---

# %%
# how many Rows X Cols are there ?
nba.shape
# Out:
# (458, 9)

# %%
# column titles
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
# columns & DataTypes
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
# 💡 Please Note: Object DataType in Pandas Represents String Data.
# (String isn't available in Pandas we Use Object Instead)

# %%
# .Describe() : this method returns statistical or numerical Facts for all the numerical Columns Present in DataFrame.

nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
# .info(): this method returns the detailed summary of dataframe
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# Column Name | Count of Values Present in Column
# ---
# ![image.png](data:image/png;base64,...)

# %%
# this expression returns the count of missing values in each column! (is this mathematics or analysis)
nba.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
# head() : this function returns the first 5 Rows
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# tail():  this function returns the last five rows
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %% [markdown]
# # 💡 Quick Fact : NaN in Pandas Represents the Missing or Absent Value.

# %%
# you can also specify count of rows

nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %% [markdown]
# # 💻 Accessing a Single Column
# ---

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# Syntax1 : <DataFrame>.ColumnName
nba.Name.head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
# Syntax2 : <DataFrame>[ColumnName]
nba['Name'].head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %% [markdown]
# 😕 What is the difference in Both Syntax?
# ---
# <pre>
# answer: you cannot access column where titles are having spaces using (dot) Expression.
#
# eg.
#
# assuming there is a column named 'my college'
#
# nba.my college      ❌
#
# nba['my college']   ✅

# %%
# let us do a small practical

# %%
# Adding A new Column

nba['my sport'] = 'Basketball'

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary    my sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba.my sport
# Out:
#   File "<ipython-input-34-5afbc817236b>", line 1
#     nba.my sport
#            ^
# SyntaxError: invalid syntax

# %%
nba['my sport']
# Out:
# 0      Basketball
# 1      Basketball
# 2      Basketball
# 3      Basketball
# 4      Basketball
#           ...
# 453    Basketball
# 454    Basketball
# 455    Basketball
# 456    Basketball
# 457    Basketball
# Name: my sport, Length: 458, dtype: object

# %%
# here is how we Delete the column!

del nba['my sport']

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# # 💻  Accessing Multiple Columns
# ---

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# 1: define a  list containing choice of columns.
mycols = ['Name' ,'College','Salary']
# 2. pass list withing square brackets in DataFrame
nba[ mycols ].head()
# Out:
#             Name            College     Salary
# 0  Avery Bradley              Texas  7730337.0
# 1    Jae Crowder          Marquette  6796117.0
# 2   John Holland  Boston University        NaN
# 3    R.J. Hunter      Georgia State  1148640.0
# 4  Jonas Jerebko                NaN  5000000.0

# %%
# Here is how Direct Expression Looks Like
nba[ ['Name','College','Salary']].head()
# Out:
#             Name            College     Salary
# 0  Avery Bradley              Texas  7730337.0
# 1    Jae Crowder          Marquette  6796117.0
# 2   John Holland  Boston University        NaN
# 3    R.J. Hunter      Georgia State  1148640.0
# 4  Jonas Jerebko                NaN  5000000.0

# %% [markdown]
# # 💻 Filtering Rows (Important)
# ---

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %% [markdown]
# 🍎 you are Asked to find all Players from 'Texas' College.

# %%
# 1. create condition
c1 = nba.College == 'Texas'
# 2. Pass condition into DataFrame
nba[ c1 ]
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %%
# Here is how you can do it using Direct Expression
nba[    nba.College == 'Texas' ]
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %% [markdown]
# # 🏆 You are asked to Find Only Players who are 25 or Younger
# ---

# %% [markdown]
# 💡 Creating DataFrame for Simplifying Problem Solving is Suggested !

# %%
youngPlayers = nba[ nba.Age <=25 ]

# %%
# count of rows
len(youngPlayers)     # or younPlayers.shape
# Out:
# 199

# %% [markdown]
# # 💻 Handling Multiple Conditions
# ---

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %% [markdown]
# 🏆 You are Aksed to Find Players from 'Texas' College Playing from 'PG' Position.

# %%
c1 = nba.College  == 'Texas'
c2 = nba.Position == 'PG'

nba[ c1 & c2 ]             # Here & is Logical AND
# Out:
#               Name             Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley   Boston Celtics     0.0       PG  25.0    6-2   180.0
# 66     Cory Joseph  Toronto Raptors     6.0       PG  24.0    6-3   190.0
# 384  D.J. Augustin   Denver Nuggets    12.0       PG  28.0    6-0   183.0
#
#     College     Salary
# 0     Texas  7730337.0
# 66    Texas  7000000.0
# 384   Texas  3000000.0

# %%
# here is how you do it using Direct Expression

nba[  (nba.College == 'Texas') & (nba.Position == 'PG' ) ]
# Out:
#               Name             Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley   Boston Celtics     0.0       PG  25.0    6-2   180.0
# 66     Cory Joseph  Toronto Raptors     6.0       PG  24.0    6-3   190.0
# 384  D.J. Augustin   Denver Nuggets    12.0       PG  28.0    6-0   183.0
#
#     College     Salary
# 0     Texas  7730337.0
# 66    Texas  7000000.0
# 384   Texas  3000000.0

# %% [markdown]
# # 🏆  You are Asked to Find players from 'Toronto Raptors' Team and are 25 or Younger.
# ---

# %%
nba[ (nba.Team == 'Toronto Raptors') & ( nba.Age <=25)].shape
# Out:
# (8, 9)

# %% [markdown]
# #### 💻 using OR Operator i.e  |
# ---
# Finding Players from either 'Boston Celtics' or 'Denver Nuggets' Team.

# %%
nba [         (nba.Team == 'Boston Celtics')  |     (nba.Team == 'Denver Nuggets') ]
# Out:
#                   Name            Team  Number Position   Age Height  Weight  \
# 0        Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1          Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2         John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3          R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4        Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5         Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6        Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7         Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8         Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9         Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10     Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# ...

# %% [markdown]
# ## 💻 Finding Players Whose Salary Data is Unavailable i.e. NaN
# ---

# %%
nba[  nba.Salary.isnull() ]
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %% [markdown]
# #😕 Can you think of concept that can help me find only players whose Salary is Available ?

# %%
nba[ ~  nba.Salary.isnull() ]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %% [markdown]
# # 💻 Sorting
# ---

# %%
# you are asked to sort players by their age in Descending Order!

# %%
nba.sort_values( by ='Age' , ascending=False)

# here ascending=True means Ascending Order
# here ascending=False means descending Order
# Out:
#                Name                    Team  Number Position   Age Height  \
# 304    Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400   Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 298      Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 261    Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
# 102  Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# ..              ...                     ...     ...      ...   ...    ...
# 401      Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# 60   Christian Wood      Philadelphia 76ers    35.0       PF  20.0   6-11
# 226   Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122    Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College     Salary
# 304   200.0            Utah   250750.0
# ...

# %% [markdown]
# # 🌈 You are asked to Find the Highest Paid Player Name from 'Texas' College Playing from 'PG' Position
# ---

# %%
texasPlayers = nba [ (nba.College == 'Texas') & (nba.Position == 'PG')]

# %%
texasPlayers.sort_values(by='Salary',ascending=False).head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
texasPlayers.sort_values(by='Salary',ascending=False).head(1)['Name']
# Out:
# 0    Avery Bradley
# Name: Name, dtype: object

# %% [markdown]
# # 💻 Here are some Important Analytical Functions One Must Know! (Important)
# ---

# %%
# .nunique() : this function returns the count of unique values.

nba.Team.nunique()
# Out:
# 30

# %%
# how many Colleges are listed in Data ?

# %%
# .unique(): this function returns all the unique/distinct values

nba.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz',
#        nan], dtype=object)

# %%
# what are the unique Playing Positions available in Data ?

# %%
nba.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C', nan], dtype=object)

# %%
# .value_counts() : this function returns the frequency or occurence count of each unique value present in column.

# %%
nba.Position.value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %%
# Here is the Explanation

# sampleData :  🦁 🐶 🦁  🐱 🐶 🦁 🦁

# nunique : count of unique values :                      3

# unique  : returns unique values  :                     🐱 🐶 🦁

# value_counts:     returns uniqueValue and its occurence count i.e frequency

#  🦁    4
#  🐶    2
#  🐱    1

# %% [markdown]
# # 🏆 Quick Activity:
# ---
# You are asked to find count of players in Each Team!

# %%
nba.Team.value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
nba.Position.value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %% [markdown]
# 💡 you can add Normalize=True Parameter in Value_counts to Change the Numbers (frequency) into Percentage Distribution.

# %%
nba.Position.value_counts(normalize=True) * 100
# Out:
# Position
# SG    22.319475
# PF    21.881838
# PG    20.131291
# SF    18.599562
# C     17.067834
# Name: proportion, dtype: float64

# %%
nba.Position.value_counts(normalize=True).plot(kind='pie');

# %% [markdown]
# # 😋 Foods.csv
# ---
#
# Link :
#
# https://drive.google.com/file/d/190TGPNlTRN9d_Lu8d6jBkrgM5NMtP5wb/view?usp=sharing

# %%
foods = pd.read_csv('foods.csv')

# %%
foods.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %% [markdown]
# 💡How Many Food Transaction Records are Available in Data ?

# %%
len(foods)
# Out:
# 1000

# %% [markdown]
# 💡 Who chomps more chow , dudes or dames ?

# %%
foods.Gender.value_counts()
# Out:
# Gender
# Female    512
# Male      488
# Name: count, dtype: int64

# %%
foods.Gender.value_counts(normalize=True) * 100
# Out:
# Gender
# Female    51.2
# Male      48.8
# Name: proportion, dtype: float64

# %%
foods.Gender.value_counts(normalize=True).plot(kind='bar');

# %%
foods.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %% [markdown]
# 💡 find the name of all unique cities present in Data !

# %%
foods.City.unique().tolist()
# Out:
# ['Stamford', 'New York', 'Philadelphia']

# %% [markdown]
# 💡 How Many Total Orders Are Placed from New York on a Weekly Basis !
# ---

# %%
foods[(foods.City=='New York') & (foods.Frequency=='Weekly')].shape
# Out:
# (43, 6)

# %% [markdown]
# 💡 Which is the Hottest Selling Product in the Daily Category !
# ---

# %%
foods[ foods.Frequency == 'Daily'].Item.value_counts()
# Out:
# Item
# Donut        30
# Burrito      27
# Sushi        25
# Burger       24
# Ice Cream    18
# Chalupa      13
# Name: count, dtype: int64

# %% [markdown]
# # 🍩

# %% [markdown]
# # 🤔 Who Spends More on Food , Male or Female ?
# ---

# %%
# method  1
foods[ foods.Gender == 'Male'].Spend.sum()
# Out:
# 24106.04

# %%
foods[ foods.Gender == 'Female'].Spend.sum()
# Out:
# 25963.33

# %%
# this is how advance pandas looks like

foods.groupby('Gender')['Spend'].sum()
# Out:
# Gender
# Female    25963.33
# Male      24106.04
# Name: Spend, dtype: float64

# %% [markdown]
# 👋🏾 End of Session
